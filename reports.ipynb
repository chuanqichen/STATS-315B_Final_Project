# %%
import numpy as np
from data_util import *
from train import *
from model import *
import data_util
from torchview import draw_graph
from util import device
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model_graph = draw_graph(NueralNet(dim_out=4), input_size=(8, 3, 30,32), expand_nested=True)
model_graph.visual_graph

# %%
# pose
task_reader=dataset_pose_task_loader
train_dataset = ImageTargetDataset("./data/", "trainset/all_train.list_1", task_reader=task_reader)
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=4, shuffle=True)
train_features, train_labels = next(iter(train_dataloader))
imshow(torchvision.utils.make_grid(train_features.permute(0, 3, 1, 2), nrow=2))

# %%
# expression
FER_train_dataset, FER_val_dataset, FER_test_dataset = data_util.getFERDataset()
#train_combined_dataset = ConcatDataset([train_dataset, FER_train_dataset])
#train_dataloader = torch.utils.data.DataLoader(train_combined_dataset, batch_size=batch_size, shuffle=True, num_workers=4)
train_dataloader = torch.utils.data.DataLoader(FER_train_dataset, batch_size=4, shuffle=True, num_workers=1)
# Out:
# ['angry', 'happy', 'neutral', 'sad']
# {'angry': 0, 'happy': 1, 'neutral': 2, 'sad': 3}

# %%
train_features, train_labels = next(iter(train_dataloader))
imshow(torchvision.utils.make_grid(train_features.permute(0, 3, 1, 2), nrow=2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 2
#       1 train_features, train_labels = next(iter(train_dataloader))
# ----> 2 imshow(torchvision.utils.make_grid(train_features.permute(0, 3, 1, 2), nrow=2))
#
# File ~/Projects/STATS-315B_Final_Project/data_util.py:96, in imshow(img)
#      94 def imshow(img):
#      95     npimg = img.numpy()
# ---> 96     plt.imshow(np.transpose(npimg, (1, 2, 0)))
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/stats315b/lib/python3.10/site-packages/matplotlib/pyplot.py:2695, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2689 @_copy_docstring_and_deprecators(Axes.imshow)
#    2690 def imshow(
#    2691         X, cmap=None, norm=None, *, aspect=None, interpolation=None,
# ...

# %%
plt.imshow(train_features[0][1])

# %%
train_features.shape
# Out:
# torch.Size([4, 3, 224, 224])

# %%
model_graph = draw_graph(NueralNetsEnsemble(dim_out=4), input_size=(8, 3, 30,32), expand_nested=True)
model_graph.visual_graph

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 train_features, train_labels = next(iter(train_dataloader))
# ----> 2 imshow(torchvision.utils.make_grid(train_features.permute(0, 3, 1, 2), nrow=2))
#
# File ~/Projects/STATS-315B_Final_Project/data_util.py:96, in imshow(img)
#      94 def imshow(img):
#      95     npimg = img.numpy()
# ---> 96     plt.imshow(np.transpose(npimg, (1, 2, 0)))
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/stats315b/lib/python3.10/site-packages/matplotlib/pyplot.py:2695, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2689 @_copy_docstring_and_deprecators(Axes.imshow)
#    2690 def imshow(
#    2691         X, cmap=None, norm=None, *, aspect=None, interpolation=None,
# ...

# %%
model_graph = draw_graph(NueralNetsEnsemble(dim_out=4), input_size=(8, 3, 30,32), expand_nested=True)
model_graph.visual_graph
